# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/Ducat/Desktop/marks.txt")

# %%
data
# Out:
#    Roll     Name  marks
# 0     1  Krishna    300
# 1     2   Piyush    400
# 2     3   Yuvika    500

# %%
df_iris=pd.read_csv(r"C:\Users\Ducat\Desktop\dataset\analysis\Iris (1).csv")
df_iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df_iris2=pd.read_csv("C:\\Users\\Ducat\\Desktop\\dataset\\analysis\\Iris (1).csv")

# %%
X=df_iris.iloc[4:,[1,3,4]]

# %%
X
# Out:
#      SepalLengthCm  PetalLengthCm  PetalWidthCm
# 4              5.0            1.4           0.2
# 5              5.4            1.7           0.4
# 6              4.6            1.4           0.3
# 7              5.0            1.5           0.2
# 8              4.4            1.4           0.2
# ..             ...            ...           ...
# 145            6.7            5.2           2.3
# 146            6.3            5.0           1.9
# 147            6.5            5.2           2.0
# 148            6.2            5.4           2.3
# 149            5.9            5.1           1.8
#
# [146 rows x 3 columns]

# %%
y=df_iris.iloc[:,5].values

# %%
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
df=pd.read_csv(r"C:\Users\Ducat\Desktop\dataset\analysis\Iris (1).csv",usecols=[1,2,3,4,5])

# %%
X=df.iloc[:,:4].values

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
import numpy as np
X_feature=np.array(X)

# %%
X_feature
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
model.fit(X_feature,y)
# Out:
# KNeighborsClassifier()

# %%
sample=[[1.3,2.3,3.4,2.1]]
model.predict(sample)
model.predict_proba(sample)
# Out:
# array([[0. , 0.8, 0.2]])

# %%
from sklearn.neighbors import KNeighborsRegressor
model1=KNeighborsRegressor()
model1.fit(X_feature,y)
# Out:
# KNeighborsRegressor()

# %%
model1.predict(sample)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 model1.predict(sample)
#
# File ~\anaconda3\lib\site-packages\sklearn\neighbors\_regression.py:238, in KNeighborsRegressor.predict(self, X)
#     235     _y = _y.reshape((-1, 1))
#     237 if weights is None:
# --> 238     y_pred = np.mean(_y[neigh_ind], axis=1)
#     239 else:
#     240     y_pred = np.empty((X.shape[0], _y.shape[1]), dtype=np.float64)
#
# File <__array_function__ internals>:5, in mean(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440, in mean(a, axis, dtype, out, keepdims, where)
#    3437     else:
#    3438         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3440 return _methods._mean(a, axis=axis, dtype=dtype,
#    3441                       out=out, **kwargs)
#
# ...

# %%
import pandas as pd

df1=pd.read_excel(r'C:\Users\Ducat\Desktop\salary data.xlsx')
df1

# %%
X1=df1.iloc[:,:1].values
X1

# %%
y1=df1.iloc[:,1].values
y1

# %%
from sklearn.neighbors import KNeighborsRegressor

model2=KNeighborsRegressor(n_neighbors=6)
model2.fit(X1,y1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 4>()
#       1 from sklearn.neighbors import KNeighborsRegressor
#       3 model2=KNeighborsRegressor(n_neighbors=6)
# ----> 4 model2.fit(X1,y1)
#
# NameError: name 'X1' is not defined

# %%
model2.predict([[10]])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 model2.predict([[10]])
#
# File ~\anaconda3\lib\site-packages\sklearn\neighbors\_regression.py:229, in KNeighborsRegressor.predict(self, X)
#     215 def predict(self, X):
#     216     """Predict the target for the provided data.
#     217
#     218     Parameters
#    (...)
#     227         Target values.
#     228     """
# --> 229     neigh_dist, neigh_ind = self.kneighbors(X)
#     231     weights = _get_weights(neigh_dist, self.weights)
#     233     _y = self._y
#
# File ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py:700, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     647 def kneighbors(self, X=None, n_neighbors=None, return_distance=True):
#     648     """Find the K-neighbors of a point.
#     649
# ...

# %%
model2.predict([[11]])

# %%
from sklearn.linear_model import LinearRegression

model3=LinearRegression()
model3.fit(X1,y1)
model3.predict([[10]])

# %%
model3.predict([[11]])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 model3.coef_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'
