# %%
print("hello world")
print("this is krishna")
print("I am 27)
print("bye")
# Out:
#   Cell In[5], line 3
#     print("I am 27)
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
# Out:
# bye

# %%
def intro():
    print("This is krishna)
    a=int("10.0")

def intro2():
    print("this is my official intro")

# %%
from threading import Thread

# %%
t1=Thread(target=intro,name="Introduction thread")
t2=Thread(target=intro2,name="Introduction of krishna")

# %%
t1.start()
# Out:
# This is krishna
# Exception in thread Introduction thread:
# Traceback (most recent call last):
#   File "c:\Users\Ducat\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\Users\Ducat\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Ducat\AppData\Local\Temp\ipykernel_1880\742208379.py", line 3, in intro
# ValueError: invalid literal for int() with base 10: '10.0'

# %%
t2.start()
# Out:
# this is my official intro

# %%
# def intro():
#     for i in range(1000):
#         print("hello")

# def intro2():
#     for i in range(1000):
#         print("hi")

# %%
# import time
# t1=Thread(target=intro)
# t2=Thread(target=intro2)
# t1.start()
# time.sleep(1)
# t2.start()
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
import time
from threading import Thread
def intro():
    for i in range(1000):
        print("hello")
        time.sleep(1)
def intro2():
    for i in range(1000):
        print("hi")
        time.sleep(1)


t1=Thread(target=intro)
t2=Thread(target=intro2)
t1.start()

t2.start()
# Out:
# hello
# hi
# hellohi
#
# hihello
#
# hello
# hi
# hihello
#
# hellohi
#
# hi
# hello
# hi
# hello
# hi
# hello
# hellohi
#
# hellohi
#
# hi
# hello
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hihello
#
# hihello
#
# hihello
#
# hihello
#
# hihello
#
# hihello
#
# hellohi
#
# hellohi
#
# hihello
#
# hihello
#
# hellohi
#
# hellohi
#
# hihello
#
# hello
# hi
# hihello
#
# hihello
#
# hihello
#
# hello
# hi
# hello
# hi
# hihello
#
# hihello
#
# hihello
#
# hihello
#
# hello
# hi
# hihello
#
# hellohi
#
# hellohi
#
# hellohi
#
# hellohi
#
# hellohi
#
# hellohi
#
# hellohi
#
# hellohi
#
# hi
# hello
# hellohi
#
# hellohi
#
# hi
# hello
# hi
# hello
# hellohi
#
# hellohi
#
# hihello
#
# hello
# hi
# hihello
#
# hello
# hi
# hihello
#
# hello
# hi
# hihello
#
# hihello
#
# hihello
#
# hello
# hi
# hihello
#
# hellohi
#
# hellohi
#
# hellohi
#
# hi
# hello
# hi
# hello
# hi
# hello

# %%
print("hello ")
# Out:
# hi
# hello
# hello
# hi
# hello
# hi
# hello
# hihello
#
# hello
# hi
# hihello
#
# hihello
#
# hello
# hi
# hihello
#
# hellohi
#
# hellohi
#
# hi
# hello
# hi
# hello
# hellohi
#
# hi
# hello
# hi
# hello
# hihello
#
# hihello
#
# hellohi
#
# hellohi
#
# hihello
#
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hellohi
#
# hellohi
#
# hellohi
#
# hellohi
#
# hi
# hello
# hellohi
#
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hihello
#
# hihello
#
# hihello
#
# hello
# hi
# hihello
#
# hello
# hi
# hi
# hello
# hellohi
#
# hellohi
#
# hello
# hi
# hello
# hi
# hellohi
#
# hi
# hello
# hihello
#
# hihello
#
# hello
# hi
# hihello
#
# hihello
#
# hello
# hi
# hihello
#
# hellohi
#
# hihello
#
# hellohi
#
# hellohi
#
# hellohi
#
# hi
# hello
# hi
# hello
# hi
# hello
# hellohi
#
# hellohi
#
# hello
# hi
# hi
# hello

# %%
import time
from threading import Thread
def intro():
    print("hello ")
def intro2():
    a=input("enter 1st number :")
    b=input("enter 2nd number :")
def bye():
    print("bye")

t1=Thread(target=intro)
t2=Thread(target=intro2)
t3=Thread(target=bye)
t1.start()
t2.start()
t3.start()
# Out:
# hello
# bye
# enter 2nd number :
